# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
from google_play_scraper import Sort, reviews_all
import pandas as pd
import numpy as np
import argparse
from posgres_conn import get_engine_from_settings

# %%
app_id = 'com.tencent.qqlivei18n'
app_name = 'wetv'
language = 'id'
country = 'id'
table_name = 'reviews'

#ingest all the newest reviews in google play
results = reviews_all(
    app_id=app_id,
    sleep_milliseconds=0, # defaults to 0
    lang=language, # defaults to 'en'
    country=country, # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=4'>5</a> table_name = 'reviews'
#       <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=6'>7</a> #ingest all the newest reviews in google play
# ----> <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=7'>8</a> results = reviews_all(
#       <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=8'>9</a>     app_id=app_id,
#      <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=9'>10</a>     sleep_milliseconds=0, # defaults to 0
#      <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=10'>11</a>     lang=language, # defaults to 'en'
#      <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=11'>12</a>     country=country, # defaults to 'us'
#      <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=12'>13</a>     sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
#      <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/Untitled-1.ipynb#ch0000000?line=13'>14</a> )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py:129, in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=125'>126</a> result = []
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=127'>128</a> while True:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=128'>129</a>     _result, continuation_token = reviews(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=129'>130</a>         app_id,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=130'>131</a>         count=MAX_COUNT_EACH_FETCH,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=131'>132</a>         continuation_token=continuation_token,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=132'>133</a>         **kwargs
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=133'>134</a>     )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=135'>136</a>     result += _result
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=137'>138</a>     if continuation_token.token is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py:93, in reviews(app_id, lang, country, sort, count, filter_score_with, continuation_token)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=89'>90</a>     _fetch_count = MAX_COUNT_EACH_FETCH
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=91'>92</a> try:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=92'>93</a>     review_items, token = _fetch_review_items(
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=93'>94</a>         url, app_id, sort, _fetch_count, filter_score_with, token
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=94'>95</a>     )
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=95'>96</a> except (TypeError, IndexError):
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=96'>97</a>     token = None
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py:36, in _fetch_review_items(url, app_id, sort, count, filter_score_with, pagination_token)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=27'>28</a> def _fetch_review_items(
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=28'>29</a>     url: str,
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=29'>30</a>     app_id: str,
#    (...)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=33'>34</a>     pagination_token: Optional[str],
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=34'>35</a> ):
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=35'>36</a>     dom = post(
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=36'>37</a>         url,
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=37'>38</a>         Formats.Reviews.build_body(
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=38'>39</a>             app_id,
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=39'>40</a>             sort,
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=40'>41</a>             count,
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=41'>42</a>             "null" if filter_score_with is None else filter_score_with,
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=42'>43</a>             pagination_token,
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=43'>44</a>         ),
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=44'>45</a>         {"content-type": "application/x-www-form-urlencoded"},
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=45'>46</a>     )
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=47'>48</a>     match = json.loads(Regex.REVIEWS.findall(dom)[0])
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/features/reviews.py?line=49'>50</a>     return json.loads(match[0][2])[0], json.loads(match[0][2])[-1][-1]
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py:24, in post(url, data, headers)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py?line=22'>23</a> def post(url: str, data: Union[str, bytes], headers: dict) -> str:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py?line=23'>24</a>     return _urlopen(Request(url, data=data, headers=headers))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py:20, in _urlopen(obj)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py?line=14'>15</a>     else:
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py?line=15'>16</a>         raise ExtraHTTPError(
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py?line=16'>17</a>             "App not found. Status code {} returned.".format(e.code)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py?line=17'>18</a>         )
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/google_play_scraper/utils/request.py?line=19'>20</a> return resp.read().decode("UTF-8")
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py:462, in HTTPResponse.read(self, amt)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=456'>457</a> else:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=457'>458</a>     # Amount is not given (unbounded read) so we must check self.length
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=458'>459</a>     # and self.chunked
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=460'>461</a>     if self.chunked:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=461'>462</a>         return self._readall_chunked()
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=463'>464</a>     if self.length is None:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=464'>465</a>         s = self.fp.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py:572, in HTTPResponse._readall_chunked(self)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=569'>570</a>     if chunk_left is None:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=570'>571</a>         break
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=571'>572</a>     value.append(self._safe_read(chunk_left))
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=572'>573</a>     self.chunk_left = 0
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=573'>574</a> return b''.join(value)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py:609, in HTTPResponse._safe_read(self, amt)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=601'>602</a> def _safe_read(self, amt):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=602'>603</a>     """Read the number of bytes requested.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=603'>604</a>
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=604'>605</a>     This function should be used when <amt> bytes "should" be present for
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=605'>606</a>     reading. If the bytes are truly not available (due to EOF), then the
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=606'>607</a>     IncompleteRead exception can be used to detect the problem.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=607'>608</a>     """
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=608'>609</a>     data = self.fp.read(amt)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=609'>610</a>     if len(data) < amt:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py?line=610'>611</a>         raise IncompleteRead(data, amt-len(data))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py?line=666'>667</a> while True:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py?line=667'>668</a>     try:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py?line=668'>669</a>         return self._sock.recv_into(b)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py?line=669'>670</a>     except timeout:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py?line=670'>671</a>         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1236'>1237</a>     if flags != 0:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1237'>1238</a>         raise ValueError(
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1238'>1239</a>           "non-zero flags not allowed in calls to recv_into() on %s" %
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1239'>1240</a>           self.__class__)
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1240'>1241</a>     return self.read(nbytes, buffer)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1241'>1242</a> else:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1242'>1243</a>     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1096'>1097</a> try:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1097'>1098</a>     if buffer is not None:
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1098'>1099</a>         return self._sslobj.read(len, buffer)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1099'>1100</a>     else:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py?line=1100'>1101</a>         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#create dataframe and transform
df = pd.DataFrame(np.array(results), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df['language'] = language
df['country'] = country
df['app_name'] = app_name
df['sentiment_score'] = 0.0
df['sentiment_label'] = None
df['source'] = 'google play store'

df = df.rename(columns={"reviewId":"review_id",
                        #"userName":"username",
                        "reviewCreatedVersion":"version",
                        "at":"date"})
                        #"thumbsUpCount":"tumbs_up_count",
                        #"replyContent":"replied_content",
                        #"repliedAt":"replied_date",
                        #"content":"content_text"})
df = df[['review_id','date','app_name','version','source','language','country','content','score','sentiment_score','sentiment_label']]
df['review_id'] = df['review_id'].str[3:]

# %%
#load to postgresql
engine = get_engine_from_settings()
df.head(n=0).to_sql(name=table_name, con=engine, if_exists='replace')
df.to_sql(name=table_name, con=engine, if_exists='append')
