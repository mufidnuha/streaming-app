# %%
import pandas as pd
from posgres_conn import get_engine_from_settings
import re
import emoji
from nltk import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Sentiment Analysis") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# 22/03/08 08:38:47 WARN Utils: Your hostname, MacBook-Air-Mufida.local resolves to a loopback address: 127.0.0.1; using 192.168.1.31 instead (on interface en0)
# 22/03/08 08:38:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/03/08 08:38:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
engine = get_engine_from_settings()

#extract from postgresql
query = """SELECT review_id, content, score
            FROM reviews r
            WHERE language='id'
        """
pdf = pd.read_sql_query(query, engine)

# %%
df = spark.createDataFrame(pdf)
df = df.repartition(24)
df.write.mode('overwrite').parquet('reviews/lang_id/')
# Out:
# 22/03/08 08:39:57 WARN TaskSetManager: Stage 0 contains a task of very large size (8598 KiB). The maximum recommended task size is 1000 KiB.
# 22/03/08 08:40:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 22/03/08 08:40:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 22/03/08 08:40:06 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 22/03/08 08:40:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 22/03/08 08:40:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 22/03/08 08:40:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 22/03/08 08:40:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 22/03/08 08:40:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 22/03/08 08:40:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers

# %%
def remove_special_char(text):
    new_text = re.sub(r"[^a-zA-Z\s]","", text)
    new_text = re.sub(emoji.get_emoji_regexp(), r"", new_text)
    new_text = re.sub(r'^\s*$', "", new_text)
    new_text = re.sub(r'^([0-9]*)$', "", new_text)
    return new_text

def remove_multiple_char(text):
    text_token = word_tokenize(text)

    words = []
    for word in text_token:
        if re.search(r"(.)\1{2,}", word):
            new_word = re.split(r"(.)\1{2,}", word)
            new_word = ''.join(new_word)
        else:
            new_word = word
        words.append(new_word)
    new_text = ' '.join(words)
    return new_text

def cleaning(df):
    #case folding
    df['content'] = df['content'].str.lower()

    #remove special character
    df['content'] = df['content'].apply(remove_special_char)

    #remove multiple character
    df['content'] = df['content'].apply(remove_multiple_char)

    #remove blank row
    df.dropna(inplace=True)

    return df

def stemming(stemmer, words):
    # stemming process
    stem_words = [stemmer.stem(word) for word in words]
    return stem_words

def filter_stopwords(words):
    stop_words = set(stopwords.words('indonesian'))
    filtered_words = [word for word in words if word not in stop_words]
    return filtered_words

# %%
df = df.withColumn('sentiment_label', when(df.score <= 3,"Negative")
                                        .otherwise("Positive"))

# %%
df = df.na.drop(subset=["content"])
df = df.withColumn("content", lower(col("content"))) \
        .withColumn("content", regexp_replace("content", r"[^a-zA-Z\s]", "")) \
        .withColumn("content", regexp_replace("content", r'^\s*$', "")) \
        .withColumn("content", regexp_replace("content", r'^([0-9]*)$', ""))

# %%
df.show()
# Out:
# 22/03/08 08:50:41 WARN TaskSetManager: Stage 6 contains a task of very large size (8598 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 6:>                                                          (0 + 8) / 8]
# +--------------------+--------------------+-----+---------------+
# |           review_id|             content|score|sentiment_label|
# +--------------------+--------------------+-----+---------------+
# |AOqpTOEdQu5ZIW0W-...|                bgus|    5|       Positive|
# |AOqpTOEo9ZINuFZul...|apk nya bagus ban...|    5|       Positive|
# |AOqpTOF3WQQgiYAH3...|                  ok|    5|       Positive|
# |AOqpTOE-4nLRpnepl...|                  ok|    5|       Positive|
# |AOqpTOGnNvjdUW-vQ...|tolong diplomasi ...|    3|       Negative|
# |AOqpTOFw_b_KXzZHT...|       aku akan film|    5|       Positive|
# |AOqpTOH64h0C8rLwX...|aku kasih bintang...|    4|       Positive|
# |AOqpTOEwBMQwXXSgf...|kalau bagus nanti...|    3|       Negative|
# |AOqpTOEOHoDUGJFW4...|tiba gk bisa di b...|    1|       Negative|
# |AOqpTOHNKDdvrliO9...|gk bisa d donwloa...|    1|       Negative|
# |AOqpTOGhCUwKDfSCy...|aplikasi ga jelas...|    1|       Negative|
# |AOqpTOHt-4_XhUqZq...|      aplikasi bagus|    5|       Positive|
# |AOqpTOFvydt8eFbsZ...|            prabayar|    3|       Negative|
# |AOqpTOF7kEXSK8PFV...|wah  wetv keren b...|    5|       Positive|
# |AOqpTOESetLtSCYiy...|                  ok|    3|       Negative|
# |AOqpTOEdnxg0Unhdo...|aku baru ini down...|    2|       Negative|
# |AOqpTOEvg6TBLpMmT...|gak bisa kedownlo...|    1|       Negative|
# |AOqpTOHF66mmoV2KS...|                seru|    1|       Negative|
# |AOqpTOHxTxiT5r3VB...|keren si banyak d...|    5|       Positive|
# |AOqpTOHxz9Grldf2d...|               bagus|    5|       Positive|
# +--------------------+--------------------+-----+---------------+
# only showing top 20 rows

# %%
df['sentiment_label'] = pd.cut(df['score'], bins=[0, 3, 5], labels=['negative', 'positive'])

# %%
df[df['content'].isnull()]
# Out:
#                                                 review_id content  score  \
# 112047  AOqpTOGvymhmgsy3dQgClxcdafp37NaCFsxsEePDDQhoxY...    None      5
# 112981  AOqpTOEwAbQtLs58TQzmjorZwvd_tMVrO0mGVvZzETLOvI...    None      5
# 251326  AOqpTOGxRWoq-DWg1z1fBrwxTIFS6K7PfbdMX4SqCco1kH...    None      1
# 262790  AOqpTOEfUDJkq2ra5QiwWuCpIICNN6RBQAUwJMPhLijOMf...    None      5
# 264809  AOqpTOH2ZHo3FTq-Mi7ypQV5KwbWRs5FB58ud8kjGTGifY...    None      5
# 273009  AOqpTOGPe3ogfAJDC8_ZPKnSjfrVpA3p1aDXYWRxDJlc38...    None      1
# 277192  AOqpTOFzf5AdoiPRceyDOO-mgG_qNIOZzr403iw0AOW5-a...    None      2
# 280031  AOqpTOFeluFkTEeEe6eaJC-uVwq04Qj8sm7aF0lN-zLHQ3...    None      3
# 284050  AOqpTOESK76gz5Vwmthdl2vSzeo5COSFBbzEEM4yu30hUz...    None      5
#
#        sentiment_label
# 112047        positive
# 112981        positive
# 251326        negative
# 262790        positive
# 264809        positive
# 273009        negative
# 277192        negative
# 280031        negative
# 284050        positive

# %%
df.dropna(inplace=True)

# %%
df['content'] = df['content'].str.lower()
df['content'] = df['content'].str.replace(r"[^a-zA-Z\s]","")
df['content'] = df['content'].str.replace(emoji.get_emoji_regexp(), r"")
df['content'] = df['content'].str.replace(r'^\s*$', "")
df['content'] = df['content'].str.replace(r'^([0-9]*)$', "")
# Out:
# /var/folders/9b/3tbz57ps2vj36lwt_1gsjkdh0000gn/T/ipykernel_1114/3465736075.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['content'] = df['content'].str.replace(r"[^a-zA-Z\s]","")
# /var/folders/9b/3tbz57ps2vj36lwt_1gsjkdh0000gn/T/ipykernel_1114/3465736075.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['content'] = df['content'].str.replace(r'^\s*$', "")
# /var/folders/9b/3tbz57ps2vj36lwt_1gsjkdh0000gn/T/ipykernel_1114/3465736075.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['content'] = df['content'].str.replace(r'^([0-9]*)$', "")

# %%
df
# Out:
#                                                 review_id  \
# 0       AOqpTOF71nVO9Y_vub3RBq-zMdOQ4nbhCanCrv26sERHQX...
# 1       AOqpTOF4Z7XTt2JkuwdLuM2JHhAYvqR13uab0LncdZMIBk...
# 2       AOqpTOHuiIw15rBr1w2BC_uPaaETR2e-HOpm1eJh4rvq8y...
# 3       AOqpTOH_pL0SFUs-x-1qrEVSh_M7ItAXzNd649NpGa8t7X...
# 4       AOqpTOGumLn4cjSZEC6GN9lE0tMaGnVAh7sO9_o-O1l1FZ...
# ...                                                   ...
# 471153                   b81a2a4e9ba311eca8221eb0cae22a66
# 471154                   b81a2a9e9ba311eca8221eb0cae22a66
# 471155                   b81a2aee9ba311eca8221eb0cae22a66
# 471156                   b81a2b3e9ba311eca8221eb0cae22a66
# 471157                   b81a2ba29ba311eca8221eb0cae22a66
#
#                                                   content  score  \
# 0                                             ok bangettt      5
# 1       susah banget daftar vip nya tolong dong admin ...      1
# 2       aplikasi paling buruk jangan di download pulsa...      1
# 3                                                    gout      5
# 4                                  aku menyukai film wetv      5
# ...                                                   ...    ...
# 471153  kode otp kode otpnya tu manaaaaaaaaaa lama baa...      1
# 471154           learn from competitors we need dark mode      3
# 471155                              chromecast chromecast      1
# 471156  george lucasd be crying somewhere great conten...      3
# 471157                  its marvelous happy watchin alles      5
#
#        sentiment_label
# 0             positive
# 1             negative
# 2             negative
# 3             positive
# 4             positive
# ...                ...
# 471153        negative
# 471154        negative
# 471155        negative
# 471156        negative
# 471157        positive
#
# [471149 rows x 4 columns]

# %%
df['words'] = df['content'].apply(word_tokenize)
df
# Out:
#                                                 review_id  \
# 0       AOqpTOF71nVO9Y_vub3RBq-zMdOQ4nbhCanCrv26sERHQX...
# 1       AOqpTOF4Z7XTt2JkuwdLuM2JHhAYvqR13uab0LncdZMIBk...
# 2       AOqpTOHuiIw15rBr1w2BC_uPaaETR2e-HOpm1eJh4rvq8y...
# 3       AOqpTOH_pL0SFUs-x-1qrEVSh_M7ItAXzNd649NpGa8t7X...
# 4       AOqpTOGumLn4cjSZEC6GN9lE0tMaGnVAh7sO9_o-O1l1FZ...
# ...                                                   ...
# 471153                   b81a2a4e9ba311eca8221eb0cae22a66
# 471154                   b81a2a9e9ba311eca8221eb0cae22a66
# 471155                   b81a2aee9ba311eca8221eb0cae22a66
# 471156                   b81a2b3e9ba311eca8221eb0cae22a66
# 471157                   b81a2ba29ba311eca8221eb0cae22a66
#
#                                                   content  score  \
# 0                                             ok bangettt      5
# 1       susah banget daftar vip nya tolong dong admin ...      1
# 2       aplikasi paling buruk jangan di download pulsa...      1
# 3                                                    gout      5
# 4                                  aku menyukai film wetv      5
# ...                                                   ...    ...
# 471153  kode otp kode otpnya tu manaaaaaaaaaa lama baa...      1
# 471154           learn from competitors we need dark mode      3
# 471155                              chromecast chromecast      1
# 471156  george lucasd be crying somewhere great conten...      3
# 471157                  its marvelous happy watchin alles      5
#
#        sentiment_label                                              words
# 0             positive                                     [ok, bangettt]
# 1             negative  [susah, banget, daftar, vip, nya, tolong, dong...
# 2             negative  [aplikasi, paling, buruk, jangan, di, download...
# 3             positive                                             [gout]
# 4             positive                        [aku, menyukai, film, wetv]
# ...                ...                                                ...
# 471153        negative  [kode, otp, kode, otpnya, tu, manaaaaaaaaaa, l...
# 471154        negative   [learn, from, competitors, we, need, dark, mode]
# 471155        negative                           [chromecast, chromecast]
# 471156        negative  [george, lucasd, be, crying, somewhere, great,...
# 471157        positive            [its, marvelous, happy, watchin, alles]
#
# [471149 rows x 5 columns]

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
df['words'] = df['words'].apply(lambda x: stemming(stemmer, x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 11' in <module>
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000015untitled?line=0'>1</a> df['words'] = df['words'].apply(lambda x: stemming(stemmer, x))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py:4357, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4246'>4247</a> def apply(
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4247'>4248</a>     self,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4248'>4249</a>     func: AggFuncType,
#    (...)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4251'>4252</a>     **kwargs,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4252'>4253</a> ) -> FrameOrSeriesUnion:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4253'>4254</a>     """
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4254'>4255</a>     Invoke function on values of Series.
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4255'>4256</a>
#    (...)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4354'>4355</a>     dtype: float64
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4355'>4356</a>     """
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py?line=4356'>4357</a>     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py:1043, in SeriesApply.apply(self)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1038'>1039</a> if isinstance(self.f, str):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1039'>1040</a>     # if we are a string, try to dispatch
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1040'>1041</a>     return self.apply_str()
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1042'>1043</a> return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py:1098, in SeriesApply.apply_standard(self)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1091'>1092</a>         values = obj.astype(object)._values
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1092'>1093</a>         # error: Argument 2 to "map_infer" has incompatible type
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1093'>1094</a>         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1094'>1095</a>         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1095'>1096</a>         # List[Union[Callable[..., Any], str]]]]]"; expected
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1096'>1097</a>         # "Callable[[Any], Any]"
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1097'>1098</a>         mapped = lib.map_infer(
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1098'>1099</a>             values,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1099'>1100</a>             f,  # type: ignore[arg-type]
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1100'>1101</a>             convert=self.convert_dtype,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1101'>1102</a>         )
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1103'>1104</a> if len(mapped) and isinstance(mapped[0], ABCSeries):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1104'>1105</a>     # GH 25959 use pd.array instead of tolist
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1105'>1106</a>     # so extension arrays can be used
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/apply.py?line=1106'>1107</a>     return obj._constructor_expanddim(pd_array(mapped), index=obj.index)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2859, in pandas._libs.lib.map_infer()
#
# Untitled-1.ipynb Cell 11' in <lambda>(x)
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000015untitled?line=0'>1</a> df['words'] = df['words'].apply(lambda x: stemming(stemmer, x))
#
# Untitled-1.ipynb Cell 3' in stemming(stemmer, words)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=36'>37</a> def stemming(stemmer, words):
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=37'>38</a>     # stemming process
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=38'>39</a>     stem_words = [stemmer.stem(word) for word in words]
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=39'>40</a>     return stem_words
#
# Untitled-1.ipynb Cell 3' in <listcomp>(.0)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=36'>37</a> def stemming(stemmer, words):
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=37'>38</a>     # stemming process
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=38'>39</a>     stem_words = [stemmer.stem(word) for word in words]
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=39'>40</a>     return stem_words
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/CachedStemmer.py:20, in CachedStemmer.stem(self, text)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/CachedStemmer.py?line=17'>18</a>     stems.append(self.cache.get(word))
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/CachedStemmer.py?line=18'>19</a> else:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/CachedStemmer.py?line=19'>20</a>     stem = self.delegatedStemmer.stem(word)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/CachedStemmer.py?line=20'>21</a>     self.cache.set(word, stem)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/CachedStemmer.py?line=21'>22</a>     stems.append(stem)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py:27, in Stemmer.stem(self, text)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=23'>24</a> stems = []
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=25'>26</a> for word in words:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=26'>27</a>     stems.append(self.stem_word(word))
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=28'>29</a> return ' '.join(stems)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py:36, in Stemmer.stem_word(self, word)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=33'>34</a>     return self.stem_plural_word(word)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=34'>35</a> else:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=35'>36</a>     return self.stem_singular_word(word)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py:84, in Stemmer.stem_singular_word(self, word)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=81'>82</a> """Stem a singular word to its common stem form."""
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=82'>83</a> context = Context(word, self.dictionary, self.visitor_provider)
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=83'>84</a> context.execute()
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Stemmer.py?line=85'>86</a> return context.result
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py:37, in Context.execute(self)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=33'>34</a> """Execute stemming process; the result can be retrieved with result"""
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=35'>36</a> #step 1 - 5
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=36'>37</a> self.start_stemming_process()
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=38'>39</a> #step 6
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=39'>40</a> if self.dictionary.contains(self.current_word):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py:80, in Context.start_stemming_process(self)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=76'>77</a>     return
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=78'>79</a> #step 4, 5
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=79'>80</a> self.remove_prefixes()
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=80'>81</a> if self.dictionary.contains(self.current_word):
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=81'>82</a>     return
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py:89, in Context.remove_prefixes(self)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=86'>87</a> def remove_prefixes(self):
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=87'>88</a>     for i in range(3):
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=88'>89</a>         self.accept_prefix_visitors(self.prefix_pisitors)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=89'>90</a>         if self.dictionary.contains(self.current_word):
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=90'>91</a>             return
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py:111, in Context.accept_prefix_visitors(self, visitors)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=108'>109</a> for visitor in visitors:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=109'>110</a>     self.accept(visitor)
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=110'>111</a>     if self.dictionary.contains(self.current_word):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=111'>112</a>         return self.current_word
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Stemmer/Context/Context.py?line=112'>113</a>     if self.process_is_stopped:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Dictionary/ArrayDictionary.py:10, in ArrayDictionary.contains(self, word)
#       <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Dictionary/ArrayDictionary.py?line=8'>9</a> def contains(self, word):
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/Sastrawi/Dictionary/ArrayDictionary.py?line=9'>10</a>     return word in self.words
#
# KeyboardInterrupt:

# %%
df
# Out:
# ['ok', 'bangettt']
