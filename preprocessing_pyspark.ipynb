# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pandas as pd
from posgres_conn import get_engine_from_settings
from textblob import TextBlob
from pyspark.ml.feature import Tokenizer
from googletrans import Translator
import time
import six
from google.cloud import translate_v2 as translate

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Sentiment Analysis") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# 22/03/07 07:25:05 WARN Utils: Your hostname, MacBook-Air-Mufida.local resolves to a loopback address: 127.0.0.1; using 192.168.1.31 instead (on interface en0)
# 22/03/07 07:25:05 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/03/07 07:25:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
engine = get_engine_from_settings()

#extract from postgresql
query = """SELECT review_id, content 
            FROM reviews r
            WHERE language='id'
        """
pdf = pd.read_sql_query(query, engine)

# %%
df = spark.createDataFrame(pdf)
df = df.repartition(4)
df.write.mode('overwrite').parquet('reviews/')
# Out:
# 22/03/07 07:25:21 WARN TaskSetManager: Stage 0 contains a task of very large size (8580 KiB). The maximum recommended task size is 1000 KiB.

# %%
df = spark.read.parquet('reviews/')

# %%
df = df.withColumn("content", lower(col("content")))

# %%
df = df.withColumn("content", regexp_replace("content", r"[^a-zA-Z0-9\s]", ""))
df = df.withColumn("content", regexp_replace("content", r"\n", ""))

# %%
df = df.withColumn("content", regexp_replace("content", r"^([0-9]*)$", ""))
df = df.withColumn("content", \
       when(col("content")=="" ,None) \
          .otherwise(col("content")))
df = df.withColumn("content", regexp_replace("content", r"^\s*$", ""))
df = df.withColumn("content", \
       when(col("content")=="" ,None) \
          .otherwise(col("content")))
df = df.na.drop(subset=["content"])

# %%
def translate_text(target, text):
    """Translates text into the target language.

    Target must be an ISO 639-1 language code.
    See https://g.co/cloud/translate/v2/translate-reference#supported_languages
    """
    translate_client = translate.Client()

    if isinstance(text, six.binary_type):
        text = text.decode("utf-8")

    # Text can also be a sequence of strings, in which case this method
    # will return a sequence of results for each text.
    result = translate_client.translate(text, target_language=target)
    return result["translatedText"]

# %%
translator_en_udf = udf(lambda text: translate_text('en', text), StringType())
translator_id_udf = udf(lambda text: translate_text('id', text), StringType())

# %%
df = df.withColumn("trans_en", translator_en_udf(col("content")))
df = df.withColumn("trans_id", translator_id_udf(col("trans_en")))

# %%
tokenizer = Tokenizer(inputCol="trans_id", outputCol="words")
wordsData = tokenizer.transform(df)

# %%
wordsData.show()
# Out:
# [Stage 11:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |           review_id|             content|            trans_en|            trans_id|               words|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |AOqpTOF3gbzJqhFpv...|                woww|                 wow|                 Wow|               [wow]|
# |AOqpTOFJcbTXR5dTE...|cacat kode yg dik...|defective code se...|kode rusak yang d...|[kode, rusak, yan...|
# |AOqpTOEMHREZ2NBDv...|              senang|                like|                Suka|              [suka]|
# |AOqpTOGDop3IjUrpt...|      anyaaq kimocii|      anyaaq kimocii|      anyaaq kimocii|   [anyaaq, kimocii]|
# |AOqpTOHbebKt44ltZ...|     menamba wawasan|        gain insight|    mendapat wawasan| [mendapat, wawasan]|
# |AOqpTOHgs4Xd36iwN...|min kenapa tak bi...|Min, why can&#39;...|Min kok kemaren g...|[min, kok, kemare...|
# |AOqpTOGdzJrLbeFfz...|     wetv kesukan ku|    wetv my favorite|      wetv favoritku|   [wetv, favoritku]|
# |AOqpTOEMEopV5y5Nc...|sangat di sayang kan|it is deeply regr...|  sangat disayangkan|[sangat, disayang...|
# |AOqpTOEM8jjCoPaIG...|huufffhhh harus b...|huufffhhh you hav...|huufffhhh harus j...|[huufffhhh, harus...|
# |AOqpTOH5JYimqJG73...|                kece|                swag|       barang curian|    [barang, curian]|
# |AOqpTOGs-9LA_w1f5...|kasih bintang 3 d...|Give 3 stars firs...|Berikan 3 bintang...|[berikan, 3, bint...|
# |AOqpTOGQq54lwmQLv...|          dicobadulu|        try it first|           coba dulu|        [coba, dulu]|
# |AOqpTOGz1uOJlntRN...|ilove this becaus...|ilove this becaus...|saya suka ini kar...|[saya, suka, ini,...|
# |AOqpTOG2LMk0ug7-u...|    sangat menghibur|   very entertaining|    sangat menghibur| [sangat, menghibur]|
# |AOqpTOHz2SY-wVclp...|masalah sdh di se...|The problem has b...|Masalah telah dis...|[masalah, telah, ...|
# |AOqpTOHhfGjO5BdmN...|gimna sih caranya...|how do you buy a ...|gimana cara beli ...|[gimana, cara, be...|
# |AOqpTOEDzsgrIlGBq...|film nya seruseru...|all the movies ar...|  semua filmnya seru|[semua, filmnya, ...|
# |AOqpTOE8ESniG0wHT...|ga  memuaskan pul...|I&#39;m not satis...|Saya tidak puas, ...|[saya, tidak, pua...|
# |AOqpTOGx8mL6eYDxB...|tambah lg dong ko...|add more colossal...|tambah lagi kolos...|[tambah, lagi, ko...|
# |AOqpTOF7z3wEJWnCw...|    i think not well|    i think not well|menurut saya kura...|[menurut, saya, k...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
words_pd = wordsData.toPandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/mufidnuha/Desktop/streaming-app/preprocessing_pyspark.ipynb Cell 13' in <module>
# ----> <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/streaming-app/preprocessing_pyspark.ipynb#ch0000029?line=0'>1</a> words_pd = wordsData.toPandas()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/pandas/conversion.py:67, in PandasConversionMixin.toPandas(self)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/pandas/conversion.py?line=63'>64</a> import numpy as np
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/pandas/conversion.py?line=64'>65</a> import pandas as pd
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/pandas/conversion.py?line=66'>67</a> timezone = self.sql_ctx._conf.sessionLocalTimeZone()
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/pandas/conversion.py?line=68'>69</a> if self.sql_ctx._conf.arrowPySparkEnabled():
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/pandas/conversion.py?line=69'>70</a>     use_arrow = True
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/context.py:109, in SQLContext._conf(self)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/context.py?line=105'>106</a> @property
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/context.py?line=106'>107</a> def _conf(self):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/context.py?line=107'>108</a>     """Accessor for the JVM SQL-specific configurations"""
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyspark/sql/context.py?line=108'>109</a>     return self.sparkSession._jsparkSession.sessionState().conf()
#
# AttributeError: 'str' object has no attribute 'conf'

# %%
# def translator_en(text):
#   new_text = GoogleTranslator(source='id', target='en').translate(text)#.translate_batch(list(small_test.loc[:,"Yoruba"]))
#   return new_text

# def translator_id(text):
#   new_text = GoogleTranslator(source='en', target='id').translate(text)
#   return new_text

# translator_en_udf = udf(lambda text: translator_en(text), StringType())
# translator_id_udf = udf(lambda text: translator_id(text), StringType())

# %%
# df = df.withColumn("trans_en", translator_en_udf(col("content")))
# df = df.withColumn("trans_id", translator_id_udf(col("trans_en")))

# %%
# def trans_en(text):
#     translator = Translator()
#     text = translator.translate(text, src='id', dest='en')
#     time.sleep(1)
#     return text.text
    
# def trans_id(text):
#     translator = Translator()
#     text = translator.translate(text, src='en', dest='id')
#     time.sleep(1)
#     return text.text

# %%
# trans_en_udf = udf(lambda text: trans_en(text), StringType())
# #trans_id_udf = udf(lambda text: trans_id(text), StringType())

# %%
# df = df.withColumn("trans_en", trans_en_udf(col("content")))
# #df = df.withColumn("trans_id", trans_id_udf(col("trans_en")))

# %%
#df.show()

# %%
# trans_id_udf = udf(lambda text: trans_id(text), StringType())
# df = df.withColumn("trans_id", trans_id_udf(col("trans_en")))

# %%
#df.show()

# %%
# tokenizer = Tokenizer(inputCol="trans_id", outputCol="words")
# wordsData = tokenizer.transform(df)

# %%
#wordsData.show()

# %%
import re

# %%
content = df.select('content')

# %%
tokenizer = Tokenizer(inputCol="content", outputCol="words")
wordsData = tokenizer.transform(content)

# %%
wordsData.show()
# Out:
# +--------------------+--------------------+
# |             content|               words|
# +--------------------+--------------------+
# |kenapa sekarang s...|[kenapa, sekarang...|
# |susah daftarnya u...|[susah, daftarnya...|
# |duh nyesel bgt ba...|[duh, nyesel, bgt...|
# |ntah apa laherugi...|[ntah, apa, laher...|
# |                good|              [good]|
# |                    |                  []|
# |gak tau knp eror ...|[gak, tau, knp, e...|
# |            good job|         [good, job]|
# |nonton drama kore...|[nonton, drama, k...|
# |karna bagus parah...|[karna, bagus, pa...|
# |kok ribet bnget y...|[kok, ribet, bnge...|
# |aplikasi yang san...|[aplikasi, yang, ...|
# |                  ok|                [ok]|
# |buat siapapun yg ...|[buat, siapapun, ...|
# |maaf kami tidak d...|[maaf, kami, tida...|
# |bgs sy suka hampi...|[bgs, sy, suka, h...|
# |                  gi|                [gi]|
# |seneng nonton di ...|[seneng, nonton, ...|
# |semoga bisa makin...|[semoga, bisa, ma...|
# |belum masuk apk n...|[belum, masuk, ap...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
words_list = wordsData.select('words').rdd.flatMap(lambda x: x).collect()

# %%
from itertools import chain
flatten_list = list(chain.from_iterable(words_list))

# %%
len(flatten_list)
# Out:
# 4369167

# %%
import nltk
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('indonesian'))
filtered_sentence = [w for w in flatten_list if not w in stop_words]

# %%
len(filtered_sentence)
# Out:
# 3051969

# %%
word_freq = pd.Series(filtered_sentence).value_counts()

# %%
uniqWords = sorted(set(filtered_sentence))

# %%
len(uniqWords)
# Out:
# 140612

# %%
def remove_multiple_char(word):
    if re.search(r"(.)\1{1,}", word):
        new_word = re.split(r"(.)\1{1,}", word)
        new_word = ''.join(new_word)
    else:
        new_word = word
    return new_word

# %%
uniq_word = []
for word in uniqWords:
    new_word = remove_multiple_char(word)
    uniq_word.append(new_word)

# %%
uniq_word= sorted(set(uniq_word))

# %%
len(uniq_word)
# Out:
# 120420

# %%
r = re.compile(".*[0-9].*")
uniq_word = [ s for s in uniq_word if not r.match(s) ]

# %%
len(uniq_word)
# Out:
# 112142

# %%
uniq_word[110000:]
# Out:
# ['wtch',
#  'wtefak',
#  'wtf',
#  'wtfdfd',
#  'wth',
#  'wththe',
#  'wtp',
#  'wts',
#  'wtv',
#  'wtvapl',
#  'wtvnonton',
#  'wtvsayang',
#  'wtwo',
#  'wu',
#  'wuah',
#  'wuahaplikasi',
#  'wuality',
#  'wudih',
#  'wuf',
#  'wuh',
#  'wuhu',
#  'wuhwbwcvwhwiwhehjs',
#  'wuhz',
#  'wuih',
#  'wuji',
#  'wujud',
#  'wujudkan',
#  'wuk',
#  'wukong',
#  'wulan',
#  'wulandari',
#  'wulasan',
#  'wuo',
#  'wuos',
#  'wuruk',
#  'wusbshs',
#  'wushjadi',
#  'wuw',
#  'wuwuwu',
#  'wuxia',
#  'wuxiahe',
#  'wuxian',
#  'wuxiaseperti',
#  'wuxiawushu',
#  'wuy',
#  'wuz',
#  'wv',
#  'wviusyeye',
#  'wvtv',
#  'wvwuw',
#  'wxcn',
#  'wxnx',
#  'wy',
#  'wyh',
#  'wynona',
#  'wyws',
#  'wz',
#  'wza',
#  'wzs',
#  'wzwaw',
#  'x',
#  'xa',
#  'xak',
#  'xalma',
#  'xan',
#  'xaparah',
#  'xape',
#  'xavier',
#  'xawal',
#  'xb',
#  'xblin',
#  'xbokepv',
#  'xboleh',
#  'xbox',
#  'xbugil',
#  'xbukan',
#  'xbx',
#  'xc',
#  'xcelent',
#  'xcerita',
#  'xcgjm',
#  'xcm',
#  'xcon',
#  'xcontinuex',
#  'xcv',
#  'xcx',
#  'xd',
#  'xdansex',
#  'xde',
#  'xdhfetwhfkgkfk',
#  'xdi',
#  'xdisney',
#  'xdpt',
#  'xdxz',
#  'xean',
#  'xebelin',
#  'xec',
#  'xediain',
#  'xentar',
#  'xeo',
#  'xesal',
#  'xex',
#  'xf',
#  'xfiles',
#  'xfinity',
#  'xft',
#  'xg',
#  'xgames',
#  'xgf',
#  'xh',
#  'xhamster',
#  'xhrus',
#  'xi',
#  'xia',
#  'xiang',
#  'xianxia',
#  'xiao',
#  'xiaoci',
#  'xiaojun',
#  'xiaomi',
#  'xiaoqi',
#  'xiaotong',
#  'xiaozhan',
#  'xie',
#  'xien',
#  'xiexie',
#  'xihuan',
#  'xin',
#  'xindo',
#  'xing',
#  'xingte',
#  'xingxing',
#  'xinlab',
#  'xioa',
#  'xioami',
#  'xiomei',
#  'xiomi',
#  'xiong',
#  'xionqi',
#  'xioqci',
#  'xioqiudah',
#  'xiu',
#  'xixi',
#  'xixixi',
#  'xixixixi',
#  'xixixixix',
#  'xixixixixi',
#  'xixixixixix',
#  'xixixixixixiberbagi',
#  'xixndodndoxnxodnod',
#  'xj',
#  'xjadi',
#  'xjdi',
#  'xjdjsbwueueyrhjz',
#  'xjgn',
#  'xkami',
#  'xl',
#  'xlah',
#  'xlaxis',
#  'xlaxsis',
#  'xlbagaimana',
#  'xldan',
#  'xldeasanjam',
#  'xldewas',
#  'xldewasa',
#  'xleh',
#  'xlhome',
#  'xlklo',
#  'xlnya',
#  'xlo',
#  'xlsimpati',
#  'xlsmarfren',
#  'xltelkomsel',
#  'xltrimakasih',
#  'xlu',
#  'xmasih',
#  'xmen',
#  'xmksh',
#  'xn',
#  'xnamex',
#  'xnbokep',
#  'xne',
#  'xnga',
#  'xngabisin',
#  'xngfx',
#  'xnx',
#  'xnxbangbros',
#  'xnxc',
#  'xnxco',
#  'xnxcom',
#  'xnxdotcom',
#  'xnxjapanbrouwser',
#  'xnxvidio',
#  'xo',
#  'xoba',
#  'xol',
#  'xom',
#  'xontapigt',
#  'xoraetlabourax',
#  'xox',
#  'xoxo',
#  'xoxoxo',
#  'xp',
#  'xperia',
#  'xquantyty',
#  'xr',
#  'xrama',
#  'xray',
#  'xrhelp',
#  'xrqx',
#  'xs',
#  'xsaya',
#  'xsayang',
#  'xsd',
#  'xsen',
#  'xsilang',
#  'xsis',
#  'xsiswilyzenalmutakin',
#  'xstabilyty',
#  'xstrem',
#  'xsx',
#  'xt',
#  'xterima',
#  'xterimakasih',
#  'xtp',
#  'xtpi',
#  'xtra',
#  'xtream',
#  'xtreme',
#  'xtrjmahan',
#  'xtuk',
#  'xu',
#  'xuan',
#  'xue',
#  'xukai',
#  'xuman',
#  'xuntuk',
#  'xv',
#  'xvbszye',
#  '',
#  'xvideo',
#  'xvideos',
#  'xvidi',
#  'xvidio',
#  'xvido',
#  'xvidoz',
#  'xvpn',
#  'xwalau',
#  'xy',
#  'xya',
#  'xydbxhdhdhdjdhdud',
#  'xys',
#  'xyz',
#  'xz',
#  'xzw',
#  'xzx',
#  'y',
#  'ya',
#  'yab',
#  'yabagaimana',
#  'yabagi',
#  'yabagus',
#  'yabahkan',
#  'yabai',
#  'yabalikin',
#  'yabang',
#  'yabantu',
#  'yabanyak',
#  'yabaru',
#  'yabarusan',
#  'yabayarnya',
#  'yabedainya',
#  'yabelum',
#  'yabenar',
#  'yabenarkah',
#  'yabener',
#  'yabg',
#  'yabgamana',
#  'yabiar',
#  'yabiasa',
#  'yabiasanya',
#  'yabikin',
#  'yabingung',
#  'yabintang',
#  'yabis',
#  'yabisa',
#  'yabisanya',
#  'yabkal',
#  'yabls',
#  'yabnyk',
#  'yabolak',
#  'yaboleh',
#  'yabrp',
#  'yabtw',
#  'yabuat',
#  'yabug',
#  'yabuka',
#  'yabukan',
#  'yabutuh',
#  'yabye',
#  'yac',
#  'yacape',
#  'yacapeo',
#  'yacara',
#  'yacayo',
#  'yacepat',
#  'yacepet',
#  'yach',
#  'yachanel',
#  'yachiklanya',
#  'yachklo',
#  'yachkuota',
#  'yachmau',
#  'yachpdhal',
#  'yachplease',
#  'yachsdh',
#  'yachserial',
#  'yachsetiap',
#  'yacj',
#  'yacm',
#  'yacoba',
#  'yacontohnya',
#  'yacox',
#  'yacpt',
#  'yacukup',
#  'yacuma',
#  'yacuman',
#  'yaczx',
#  'yad',
#  'yada',
#  'yadah',
#  'yadakah',
#  'yadaktautanyasayahm',
#  'yadalam',
#  'yadan',
#  'yadany',
#  'yadari',
#  'yadat',
#  'yademi',
#  'yadengan',
#  'yadg',
#  'yadi',
#  'yadikit',
#  'yadiletakan',
#  'yadimohon',
#  'yadiperbaiki',
#  'yadisemua',
#  'yadisney',
#  'yadisuruh',
#  'yaditungu',
#  'yadlu',
#  'yadmin',
#  'yadr',
#  'yadrakor',
#  'yadrama',
#  'yadri',
#  'yadt',
#  'yaduh',
#  'yadulu',
#  'yae',
#  'yaealah',
#  'yaeh',
#  'yaei',
#  'yaela',
#  'yaelah',
#  'yaelahkok',
#  'yaelahmasa',
#  'yaemang',
#  'yaemng',
#  'yaenglish',
#  'yaepisode',
#  'yaeror',
#  'yaf',
#  'yafilm',
#  'yafilma',
#  'yafilmny',
#  'yag',
#  'yaga',
#  'yagabisa',
#  'yagainya',
#  'yagak',
#  'yagal',
#  'yagambar',
#  'yagambarnya',
#  'yagantung',
#  'yagar',
#  'yagara',
#  'yagesya',
#  'yagh',
#  'yagila',
#  'yagimana',
#  'yaginama',
#  'yagitu',
#  'yagitudeh',
#  'yagk',
#  'yagmn',
#  'yagmna',
#  'yagn',
#  'yagod',
#  'yague',
#  'yagw',
#  'yah',
#  'yaha',
#  'yahabis',
#  'yahadeh',
#  'yahah',
#  'yahaha',
#  'yahahah',
#  'yahahaha',
#  'yahahahaha',
#  'yahahahahaha',
#  'yahahahahahah',
#  'yahahahahahahahajahahahah',
#  'yahahahahjajaja',
#  'yahahahayahahahahah',
#  'yahak',
#  'yahaku',
#  'yahakun',
#  'yahampun',
#  'yahaneh',
#  'yahanya',
#  'yahapa',
#  'yahapakah',
#  'yahapakarna',
#  'yahapk',
#  'yahaplikasi',
#  'yahaplikasinya',
#  'yahaq',
#  'yahari',
#  'yaharus',
#  'yaharusnya',
#  'yahasyik',
#  'yahatau',
#  'yahayo',
#  'yahbagi',
#  'yahbagus',
#  'yahbantu',
#  'yahbaru',
#  'yahbiar',
#  'yahbikin',
#  'yahbukanya',
#  'yahcara',
#  'yahcuma',
#  'yahdan',
#  'yahdi',
#  'yahdlu',
#  'yahdrama',
#  'yaheh',
#  'yahehe',
#  'yaheheh',
#  'yahehehe',
#  'yahemh',
#  'yahg',
#  'yahgagal',
#  'yahgak',
#  'yahgimana',
#  'yahgmn',
#  'yahgp',
#  'yahgx',
#  'yahini',
#  'yahitu',
#  'yahj',
#  'yahjadi',
#  'yahjangan',
#  'yahjanjikasih',
#  'yahjaringan',
#  'yahjd',
#  'yahk',
#  'yahkali',
#  'yahkalo',
#  'yahkan',
#  'yahkarena',
#  'yahkatanya',
#  'yahkaya',
#  'yahkeluar',
#  'yahklo',
#  'yahklu',
#  'yahknp',
#  'yahknpah',
#  'yahko',
#  'yahkok',
#  'yahkrna',
#  'yahksih',
#  'yahktanya',
#  'yahlagi',
#  'yahlama',
#  'yahlebih',
#  'yahloading',
#  'yahloginsaya',
#  'yahlove',
#  'yahlumayan',
#  'yahm',
#  'yahmakasih',
#  'yahmakin',
#  'yahmana',
#  'yahmasa',
#  'yahmasalah',
#  'yahmau',
#  'yahmaunya',
#  'yahmin',
#  'yahminta',
#  'yahmksdnya',
#  'yahmksh',
#  'yahmnta',
#  'yahmohon',
#  'yahmsh',
#  'yahmutar',
#  'yahmy',
#  'yahnti',
#  'yahnyesel',
#  'yaho',
#  'yahoksukses',
#  'yahot',
#  'yahp',
#  'yahpadahal',
#  'yahpadahl',
#  'yahpdahal',
#  'yahpdh',
#  'yahpdhal',
#  'yahpdhl',
#  'yahperasan',
#  'yahplease',
#  'yahplis',
#  'yahpulsa',
#  'yahrusak',
#  'yahsalam',
#  'yahsama',
#  'yahsaya',
#  'yahsebelumnya',
#  'yahsedangkan',
#  'yahsedih',
#  'yahselalu',
#  'yahsemoga',
#  'yahsering',
#  'yahsetiap',
#  'yahsoalnya',
#  'yahsolusinya',
#  'yahsperti',
#  'yahsuka',
#  'yahsy',
#  'yahtapi',
#  'yahtayangan',
#  'yahterimah',
#  'yahterimaksih',
#  'yahthaks',
#  'yahtidak',
#  'yahtlg',
#  'yahtolong',
#  'yahtpi',
#  'yahtrs',
#  'yahtrus',
#  'yahud',
#  'yahudah',
#  'yahudbye',
#  'yahudh',
#  'yahudi',
#  'yahudterimakasih',
#  'yahufth',
#  'yahulang',
#  'yahuntk',
#  'yahuntuk',
#  'yahut',
#  'yahuthuthut',
#  'yahv',
#  'yahvidio',
#  'yahwajar',
#  'yahwaktu',
#  'yahwkwkwkwkwkwkwkwkw',
#  'yahya',
#  'yahyah',
#  'yahyg',
#  'yai',
#  'yaiba',
#  'yaibademon',
#  'yaiklan',
#  'yaiklanya',
#  'yaiklas',
#  'yailah',
#  'yain',
#  'yaindosat',
#  'yainfo',
#  'yainfonya',
#  'yaini',
#  'yaintinya',
#  'yaio',
#  'yairu',
#  'yaiti',
#  'yaituanak',
#  'yaitudrama',
#  'yaituh',
#  'yaitukembalinya',
#  'yaitumnctv',
#  'yaitumon',
#  'yaituthe',
#  'yaiut',
#  'yaiy',
#  'yaiya',
#  'yaiyalah',
#  'yaj',
#  'yajadi',
#  'yajaman',
#  'yajangan',
#  'yajaringan',
#  'yajd',
#  'yajdi',
#  'yajdnya',
#  'yajelasin',
#  'yajelek',
#  'yajempol',
#  'yajg',
#  'yajgan',
#  'yajgn',
#  'yajh',
#  'yajika',
#  'yajng',
#  'yajodha',
#  'yajudulnya',
#  'yajujur',
#  'yajustru',
#  'yak',
#  'yakadang',
#  'yakak',
#  'yakalau',
#  'yakale',
#  'yakali',
#  'yakaliperbaiki',
#  'yakalo',
#  'yakalou',
#  'yakami',
#  'yakan',
#  'yakapan',
#  'yakarena',
#  'yakarna',
#  'yakasian',
#  'yakata',
#  'yakatanya',
#  'yakaya',
#  'yakayak',
#  'yakayaknya',
#  'yakayanya',
#  'yakbiar',
#  'yakd',
#  'yakdlm',
#  'yakecewa',
#  'yakegangu',
#  'yakemaren',
#  'yakemarin',
#  'yakembaranku',
#  'yakenapa',
#  'yakenapabisa',
#  'yakerja',
#  'yakeror',
#  'yaketerangan',
#  'yaketerangana',
#  'yakga',
#  'yakhan',
#  'yakhirnya',
#  'yakhusus',
#  'yakin',
#  'yakinin',
#  'yakinkah',
#  'yakinlah',
#  'yakinsebagus',
#  'yakintpi',
#  'yakira',
#  'yakirain',
#  'yakita',
#  'yakitu',
#  'yakl',
#  'yaklau',
#  'yaklo',
#  'yaklu',
#  'yakluar',
#  'yaklw',
#  'yakmemory',
#  'yakmohon',
#  'yakmrn',
#  'yakn',
#  'yaknah',
#  'yaknapa',
#  'yaknp',
#  'yaknpa',
#  'yaknpkarna',
#  'yako',
#  'yakodenya',
#  'yakog',
#  'yakok',
#  'yakomenya',
#  'yakomplit',
#  'yakorn',
#  'yakouta',
#  'yakpdhal',
#  'yakrn',
#  'yakrna',
#  'yaks',
#  'yaksetelah',
#  'yaksian',
#  'yaksub',
#  'yaktapi',
#  'yakterimakasih',
#  'yakthanks',
#  'yaktnya',
#  'yaktolong',
#  'yaku',
#  'yakudh',
#  'yakukasih',
#  'yakukira',
#  'yakult',
#  'yakun',
#  'yakuota',
#  'yakurang',
#  'yakusoku',
#  'yakuza',
#  'yakv',
#  'yakwkwkwkw',
#  'yakz',
#  'yal',
#  'yalagi',
#  'yalah',
#  'yalain',
#  'yalalu',
#  'yalan',
#  'yalanci',
#  'yalangsung',
#  'yalayanan',
#  'yalayarnya',
#  'yalemot',
#  'yalengkapin',
#  'yalg',
#  'yali',
#  'yalihat',
#  'yalin',
#  'yalngsung',
#  'yaloading',
#  'yalog',
#  'yaloh',
#  'yalouding',
#  'yalumayan',
#  'yam',
#  'yama',
#  'yamabok',
#  'yamacet',
#  'yamaf',
#  'yamafkan',
#  'yamaforang',
#  'yamaha',
#  'yamaju',
#  'yamaka',
#  'yamakasi',
#  'yamakasih',
#  'yamakin',
#  'yamaksih',
#  'yamalah',
#  'yamales',
#  'yamalesin',
#  'yaman',
#  'yamana',
#  'yamantap',
#  'yamantul',
#  'yamap',
#  'yamasa',
#  'yamasalah',
#  'yamasih',
#  'yamate',
#  'yamateh',
#  'yamato',
#  'yamau',
#  'yamazaki',
#  'yamb',
#  'yambahin',
#  'yambuh',
#  'yambung',
#  'yamemori',
#  'yamemuat',
#  'yamendapatkan',
#  'yamendingan',
#  'yamengapa',
#  'yamengunkan',
#  'yameski',
#  'yamet',
#  'yamete',
#  'yametekudasai',
#  'yametkudasi',
#  'yamg',
#  'yamhn',
#  'yamhon',
#  'yamin',
#  'yaminta',
#  'yamintak',
#  'yamisalkan',
#  'yamisalnya',
#  'yamisalnyabpake',
#  'yamkasih',
#  'yamksh',
#  'yamksih',
#  'yamksisemangat',
#  'yamn',
#  'yamnta',
#  'yamohon',
#  'yamom',
#  'yampe',
#  'yampesampe',
#  'yampon',
#  'yampun',
#  'yamsih',
#  'yamula',
#  'yamulai',
#  'yamungkin',
#  'yamuter',
#  'yamw',
#  'yan',
#  'yana',
#  'yanah',
#  'yananti',
#  'yanb',
#  'yand',
#  'yandere',
#  'yandex',
#  'yaneh',
#  'yanetflix',
#  'yanf',
#  'yang',
#  'yanga',
#  'yangada',
#  'yangak',
#  'yangakan',
#  'yangakanmenerima',
#  'yangakanmenerimasmsdari',
#  'yanganda',
#  'yangap',
#  'yangbelumkita',
#  'yangbikin',
#  'yangbisa',
#  'yangbisakitalakukan',
#  'yangbisakitalakukanuntukmembuatsebuahaplikasijaringankomputermakakanmunculagididalampremiumlebih',
#  'yangbisakitalakukanuntukyangakanditampilkandalambentuk',
#  'yangbkaya',
#  'yangblain',
#  'yangbpaling',
#  'yangbsudah',
#  'yangcolor',
#  'yangdex',
#  'yangdisambungkan',
#  'yangdramaturki',
#  'yange',
#  'yangeload',
#  'yangetik',
#  'yangful',
#  'yangke',
#  'yangla',
#  'yanglain',
#  'yanglainya',
#  'yanglalu',
#  'yanglam',
#  'yangmahakuasa',
#  'yangnonton',
#  'yangs',
#  'yangtelah',
#  'yangtidakdapatme',
#  'yangtidakmencapaitujuan',
#  'yangtiku',
#  'yangvberfaedah',
#  'yangvdari',
#  'yangvlain',
#  'yangvmau',
#  'yangyang',
#  'yangzi',
#  'yanh',
#  'yanhg',
#  'yani',
#  'yaniakun',
#  'yanianus',
#  'yaniatny',
#  'yanie',
#  'yank',
#  'yanq',
#  'yansi',
#  'yant',
#  'yantar',
#  'yanti',
#  'yanto',
#  'yantr',
#  'yantv',
#  'yanungu',
#  'yanus',
#  'yanv',
#  'yanxi',
#  'yany',
#  'yanyesel',
#  'yao',
#  'yaoh',
#  'yaoi',
#  'yaoib',
#  'yaok',
#  'yaoke',
#  'yaokeh',
#  'yaoloh',
#  'yaongyi',
#  'yaopo',
#  'yaops',
#  'yaou',
#  'yap',
#  'yapa',
#  'yapada',
#  'yapadahal',
#  'yapadahl',
#  'yapadhal',
#  'yapakah',
#  'yapakai',
#  'yapake',
#  'yapaket',
#  'yapaketandata',
#  'yapaketnya',
#  'yapapa',
#  'yaparah',
#  'yapas',
#  'yapasti',
#  'yapdahal',
#  'yapdahl',
#  'yapdhal',
#  'yapdhl',
#  'yapen',
#  'yapenasaran',
#  'yapenasarn',
#  'yapengenya',
#  'yapengin',
#  'yapenguna',
#  'yapenipu',
#  'yapeokren',
#  'yaper',
#  'yaperasan',
#  'yaperbaiki',
#  'yaperbaikin',
#  'yaperbanyakin',
#  'yapertama',
#  'yapi',
#  'yapihak',
#  'yapilihanya',
#  'yapk',
#  'yapkh',
#  'yapknya',
#  'yapl',
#  'yaplagi',
#  'yaplease',
#  'yaplikasi',
#  'yaplikasinya',
#  'yaplis',
#  'yapls',
#  'yapokoknya',
#  'yaposisi',
#  'yaps',
#  'yapto',
#  'yapulsa',
#  'yapulsaku',
#  'yapun',
#  'yapupuslah',
#  'yapusing',
#  'yapusink',
#  'yapz',
#  'yaq',
#  'yaqien',
#  'yaqin',
#  'yaqk',
#  'yaqkira',
#  'yar',
#  'yarabalalamin',
#  'yare',
#  'yarequest',
#  'yarespon',
#  'yari',
#  'yarichin',
#  'yarisih',
#  'yarobal',
#  'yarobalalamin',
#  'yarugi',
#  'yas',
#  'yasa',
#  'yasal',
#  'yasalam',
#  'yasama',
#  'yasampe',
#  'yasamsung',
#  'yasangat',
#  'yasaranya',
#  'yasasa',
#  'yasat',
#  'yasatunya',
#  'yasaya',
#  'yasayang',
#  'yasblm',
#  'yasebab',
#  'yasebel',
#  'yasebelum',
#  'yasebenernya',
#  'yasebentar',
#  'yasecara',
#  'yasedangkan',
#  'yasedih',
#  'yasegera',
#  'yasekalian',
#  ...]

# %%
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# # create stemmer
# factory = StemmerFactory()
# stemmer = factory.create_stemmer()

# # stemming process
# documents = [stemmer.stem(word) for word in filtered_sentence]
